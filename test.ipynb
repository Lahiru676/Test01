# %%
import re

# %%
text='''note 1 ffssdnuvdvnsdvndsvnds
      vsdsvjdpasvsvmadmv
      note 2 dwdvndvndsvbdvdvn cvdbdivdvd dcdnvdavdv  vovbovbv c acn
      dcdbcjn
      cdjcd
      cmdkcndkcna
      mckxldv
      note 3 ckldndnvs
      kdncvdnvds
      kcndvnldvn
      cndlvnvnklmcdc clmdvldvn lcndnvnvdnv cjpajnv'''

extract = 'note \d ([^\n]*)'
result = re.findall(extract, text)
print(result)
# Out:
# ['ffssdnuvdvnsdvndsvnds', 'dwdvndvndsvbdvdvn cvdbdivdvd dcdnvdavdv  vovbovbv c acn', 'ckldndnvs']
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Lahiru\AppData\Local\Temp\ipykernel_21772\646022815.py:13: SyntaxWarning: invalid escape sequence '\d'
#   extract = 'note \d ([^\n]*)'

# %%
text2 = '''Department of Civil Engineering, 
(2) Department of Computer Engineering, 
(3) Department of Electrical and Electronic Engineering,
(4) Department of Inter-disciplinary Studies.'''

# %%
extract2 = 'department \d ([^\n]*)'
result2 = re.findall(extract2, text2)
print(result2)
# Out:
# []
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Lahiru\AppData\Local\Temp\ipykernel_21772\2015743149.py:1: SyntaxWarning: invalid escape sequence '\d'
#   extract2 = 'department \d ([^\n]*)'

# %%
text = '''
Follow our leader Elon musk on twitter here: https://twitter.com/elonmusk, more information 
on Tesla's products can be found at https://www.tesla.com/. Also here are leading influencers 
for tesla related news,
https://twitter.com/teslarati
https://twitter.com/dummy_tesla
https://twitter.com/dummy_2_tesla'''

extrac = re.findall("https://twitter.com/([a-zA-Z0-9_]*)",text)
print(extrac)
# Out:
# ['elonmusk', 'teslarati', 'dummy_tesla', 'dummy_2_tesla']
